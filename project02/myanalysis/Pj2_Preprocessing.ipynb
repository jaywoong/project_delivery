# %%
import pandas as pd
import numpy as np

# %%
df_covid = pd.read_csv('./covid19/Covid19InfState.csv')

# %%
df01 = df_covid[['decideCnt','stateDt']]

# %%
df01.dtypes
# Out:
# decideCnt    int64
# stateDt      int64
# dtype: object

# %%
df02 = df01.astype({'decideCnt': int, 

                  'stateDt': str})

# %%
df02.dtypes
# Out:
# decideCnt     int32
# stateDt      object
# dtype: object

# %%
df02['stateDt'] = pd.to_datetime(df02['stateDt'])

# %%
df02
# Out:
#      decideCnt    stateDt
# 0            0 2020-01-01
# 1            2 2020-02-02
# 2           15 2020-02-03
# 3           15 2020-02-04
# 4           18 2020-02-05
# ..         ...        ...
# 580     201002 2021-08-02
# 581     202203 2021-08-03
# 582     203926 2021-08-04
# 583     205702 2021-08-05
# 584     207406 2021-08-06
#
# [585 rows x 2 columns]

# %%
j = df02.groupby([df02.stateDt.dt.year, df02.stateDt.dt.month]).last()

# %%
df02['date'] = df02['stateDt'].map(lambda dt: dt.replace(day=1))

# %%
df02
# Out:
#      decideCnt    stateDt       date
# 0            0 2020-01-01 2020-01-01
# 1            2 2020-02-02 2020-02-01
# 2           15 2020-02-03 2020-02-01
# 3           15 2020-02-04 2020-02-01
# 4           18 2020-02-05 2020-02-01
# ..         ...        ...        ...
# 580     201002 2021-08-02 2021-08-01
# 581     202203 2021-08-03 2021-08-01
# 582     203926 2021-08-04 2021-08-01
# 583     205702 2021-08-05 2021-08-01
# 584     207406 2021-08-06 2021-08-01
#
# [585 rows x 3 columns]

# %%
k = df02.groupby([df02.date]).last()

# %%
j
# Out:
#                  decideCnt    stateDt
# stateDt stateDt
# 2020    1                0 2020-01-01
#         2             3150 2020-02-29
#         3             9786 2020-03-31
#         4            10765 2020-04-30
#         5            11468 2020-05-31
#         6            12800 2020-06-30
#         7            14305 2020-07-31
#         8            19947 2020-08-31
#         9            23812 2020-09-30
#         10           26511 2020-10-31
#         11           34201 2020-11-30
#         12           60740 2020-12-31
# 2021    1            77395 2021-01-29
#         2            89676 2021-02-28
#         3           103088 2021-03-31
#         4           122007 2021-04-30
#         5           140340 2021-05-31
#         6           156961 2021-06-30
#         7           198345 2021-07-31
#         8           207406 2021-08-06

# %%
k
# Out:
#             decideCnt    stateDt
# date
# 2020-01-01          0 2020-01-01
# 2020-02-01       3150 2020-02-29
# 2020-03-01       9786 2020-03-31
# 2020-04-01      10765 2020-04-30
# 2020-05-01      11468 2020-05-31
# 2020-06-01      12800 2020-06-30
# 2020-07-01      14305 2020-07-31
# 2020-08-01      19947 2020-08-31
# 2020-09-01      23812 2020-09-30
# 2020-10-01      26511 2020-10-31
# 2020-11-01      34201 2020-11-30
# 2020-12-01      60740 2020-12-31
# 2021-01-01      77395 2021-01-29
# 2021-02-01      89676 2021-02-28
# 2021-03-01     103088 2021-03-31
# 2021-04-01     122007 2021-04-30
# 2021-05-01     140340 2021-05-31
# 2021-06-01     156961 2021-06-30
# 2021-07-01     198345 2021-07-31
# 2021-08-01     207406 2021-08-06

# %%
k.to_csv('Cumulative.csv')

# %%
df_del = pd.read_csv('./dlvr_call.csv', low_memory=False)

# %%
df_del.tail()
# Out:
#               SN  PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 4296266  7750546  2020-03-31               C000237                        1
# 4296267  7750548  2020-03-31               C000104                        1
# 4296268  7750550  2020-03-31               C000224                        1
# 4296269  7750552  2020-03-31               C000130                        1
# 4296270  7750553  2020-03-31               C000209                        1
#
#         DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 4296266              C000237      S0021188                족발/보쌈
# 4296267              C000102      S0021967                   치킨
# 4296268              C000224      S0035329                   분식
# 4296269              C000130      S0002286                족발/보쌈
# 4296270              C000209      S0022157                   야식
#
#          DLVR_STORE_LEGALDONG_CODE DLVR_STORE_BRTC_NM DLVR_STORE_SIGNGU_NM  \
# ...

# %%
df_del['PROCESS_DT'] = pd.to_datetime(df_del['PROCESS_DT'])

# %%
df_del.dtypes
# Out:
# SN                                    int64
# PROCESS_DT                   datetime64[ns]
# DLVR_REQUST_ENTRPS_ID                object
# DLVR_REQUST_STTUS_VALUE               int64
# DLVR_RCEPT_ENTRPS_ID                 object
# DLVR_STORE_ID                        object
# DLVR_STORE_INDUTY_NM                 object
# DLVR_STORE_LEGALDONG_CODE             int64
# DLVR_STORE_BRTC_NM                   object
# DLVR_STORE_SIGNGU_NM                 object
# DLVR_STORE_LEGALDONG_NM              object
# DLVR_STORE_LI_NM                     object
# DLVR_STORE_ADSTRD_CODE                int64
# DLVR_STORE_RDNMADR_CODE              object
# DLVR_DSTN_LEGALDONG_CODE              int64
# DLVR_DSTN_BRTC_NM                    object
# DLVR_DSTN_SIGNGU_NM                  object
# DLVR_DSTN_LEGALDONG_NM               object
# DLVR_DSTN_LI_NM                      object
# DLVR_DSTN_ADSTRD_CODE                object
# DLVR_DSTN_RDNMADR_CODE               object
# ...

# %%
df_del.tail()
# Out:
#               SN PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 4296266  7750546 2020-03-31               C000237                        1
# 4296267  7750548 2020-03-31               C000104                        1
# 4296268  7750550 2020-03-31               C000224                        1
# 4296269  7750552 2020-03-31               C000130                        1
# 4296270  7750553 2020-03-31               C000209                        1
#
#         DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# 4296266              C000237      S0021188                족발/보쌈
# 4296267              C000102      S0021967                   치킨
# 4296268              C000224      S0035329                   분식
# 4296269              C000130      S0002286                족발/보쌈
# 4296270              C000209      S0022157                   야식
#
#          DLVR_STORE_LEGALDONG_CODE DLVR_STORE_BRTC_NM DLVR_STORE_SIGNGU_NM  \
# ...

# %%
df03 = df_del['DLVR_REQUST_STTUS_VALUE'] == 1

# %%
df04 = df_del[df03]

# %%
df04
# Out:
#               SN PROCESS_DT DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# 0        3486929 2019-12-01               C000101                        1
# 1        3486930 2019-12-01               C000099                        1
# 2        3486932 2019-12-01               C000029                        1
# 3        3486933 2019-12-01               C000105                        1
# 4        3486934 2019-12-01               C000028                        1
# ...          ...        ...                   ...                      ...
# 4296266  7750546 2020-03-31               C000237                        1
# 4296267  7750548 2020-03-31               C000104                        1
# 4296268  7750550 2020-03-31               C000224                        1
# 4296269  7750552 2020-03-31               C000130                        1
# 4296270  7750553 2020-03-31               C000209                        1
#
#         DLVR_RCEPT_ENTRPS_ID DLVR_STORE_ID DLVR_STORE_INDUTY_NM  \
# ...

# %%
df05 = df04.groupby([df04.PROCESS_DT]).count()

# %%
df05
# Out:
#                            SN  PROCESS_DT  DLVR_REQUST_ENTRPS_ID  \
# PROCESS_DT PROCESS_DT
# 2019       12          627911      627911                 627911
# 2020       1           620537      620537                 620537
#            2           680265      680265                 680265
#            3           765691      765691                 765691
#            4           739668      739668                 739668
#            5           786920      786920                 786920
#
#                        DLVR_REQUST_STTUS_VALUE  DLVR_RCEPT_ENTRPS_ID  \
# PROCESS_DT PROCESS_DT
# 2019       12                           627911                627911
# 2020       1                            620537                620537
#            2                            680265                680265
#            3                            765691                765691
#            4                            739668                739668
# ...

# %%
df06 = df05['DLVR_REQUST_STTUS_VALUE']

# %%
df06
# Out:
# PROCESS_DT  PROCESS_DT
# 2019.0      12.0          627911
# 2020.0      1.0           620537
#             2.0           680265
#             3.0           765691
#             4.0           739668
#             5.0           786920
# Name: DLVR_REQUST_STTUS_VALUE, dtype: int64

# %%
df06.to_csv('order.csv')

# %%
df07 = pd.read_csv('./cumulative.csv',index_col = 'date')

# %%
df08 = pd.read_csv('./order.csv',index_col = 'date')

# %%
df07
# Out:
#         decideCnt
# date
# 202001          0
# 202002       3150
# 202003       9786
# 202004      10765
# 202005      11468
# 202006      12800
# 202007      14305
# 202008      19947
# 202009      23812
# 202010      26511
# 202011      34201
# 202012      60740
# 202101      77395
# 202102      89676
# 202103     103088
# 202104     122007
# 202105     140340
# 202106     156961
# 202107     198345
# 202108     207406

# %%
df08
# Out:
#         orders
# date
# 201912  627911
# 202001  620537
# 202002  680265
# 202003  765691
# 202004  739668
# 202005  786920

# %%
df09 = pd.merge(df07, df08, left_on='date', right_on='date', how='outer')
# Out:
#         decideCnt    orders
# date
# 202001        0.0  620537.0
# 202002     3150.0  680265.0
# 202003     9786.0  765691.0
# 202004    10765.0  739668.0
# 202005    11468.0  786920.0
# 202006    12800.0       NaN
# 202007    14305.0       NaN
# 202008    19947.0       NaN
# 202009    23812.0       NaN
# 202010    26511.0       NaN
# 202011    34201.0       NaN
# 202012    60740.0       NaN
# 202101    77395.0       NaN
# 202102    89676.0       NaN
# 202103   103088.0       NaN
# 202104   122007.0       NaN
# 202105   140340.0       NaN
# 202106   156961.0       NaN
# 202107   198345.0       NaN
# 202108   207406.0       NaN
# 201912        NaN  627911.0

# %%
df09 = df09.sort_index()

# %%
df10 = df09.fillna(0)

# %%
df_deor = df10[:6]

# %%
df_deor.to_csv('df_deor.csv')

# %%
df10 = df04.groupby([df04.PROCESS_DT]).count()

# %%
df10['DLVR_REQUST_STTUS_VALUE']
# Out:
#                SN  DLVR_REQUST_ENTRPS_ID  DLVR_REQUST_STTUS_VALUE  \
# PROCESS_DT
# 2019-12-01   9501                   9501                     9501
# 2019-12-02  14101                  14101                    14101
# 2019-12-03  15574                  15574                    15574
# 2019-12-04  15579                  15579                    15579
# 2019-12-05  17096                  17096                    17096
# ...           ...                    ...                      ...
# 2020-05-27  21330                  21330                    21330
# 2020-05-28  22614                  22614                    22614
# 2020-05-29  26455                  26455                    26455
# 2020-05-30  31377                  31377                    31377
# 2020-05-31  32146                  32146                    32146
#
#             DLVR_RCEPT_ENTRPS_ID  DLVR_STORE_ID  DLVR_STORE_INDUTY_NM  \
# PROCESS_DT
# 2019-12-01                  9501           9501                  9501
# ...

# %%
df11 = df10['DLVR_REQUST_STTUS_VALUE']

# %%
df11.shape
# Out:
# (182,)

# %%
df11
# Out:
# PROCESS_DT
# 2019-12-01     9501
# 2019-12-02    14101
# 2019-12-03    15574
# 2019-12-04    15579
# 2019-12-05    17096
#               ...
# 2020-05-27    21330
# 2020-05-28    22614
# 2020-05-29    26455
# 2020-05-30    31377
# 2020-05-31    32146
# Name: DLVR_REQUST_STTUS_VALUE, Length: 182, dtype: int64

# %%
df12 = df02[['stateDt','decideCnt']]

# %%
df12.index = df12['stateDt']

# %%
del df12['stateDt']

# %%
df12
# Out:
#             decideCnt
# stateDt
# 2020-01-01          0
# 2020-02-02          2
# 2020-02-03         15
# 2020-02-04         15
# 2020-02-05         18
# ...               ...
# 2021-08-02     201002
# 2021-08-03     202203
# 2021-08-04     203926
# 2021-08-05     205702
# 2021-08-06     207406
#
# [585 rows x 1 columns]

# %%
df20 = pd.merge(df11, df12,left_index=True, right_index=True, how='left')

# %%
df20
# Out:
#             DLVR_REQUST_STTUS_VALUE  decideCnt
# 2019-12-01                     9501        NaN
# 2019-12-02                    14101        NaN
# 2019-12-03                    15574        NaN
# 2019-12-04                    15579        NaN
# 2019-12-05                    17096        NaN
# ...                             ...        ...
# 2020-05-27                    21330    11265.0
# 2020-05-28                    22614    11344.0
# 2020-05-29                    26455    11402.0
# 2020-05-30                    31377    11441.0
# 2020-05-31                    32146    11468.0
#
# [216 rows x 2 columns]

# %%
df_reg = df20.dropna()

# %%
df_reg
# Out:
#             DLVR_REQUST_STTUS_VALUE  decideCnt
# 2020-01-01                    24385        0.0
# 2020-02-02                    27739        2.0
# 2020-02-03                    19956       15.0
# 2020-02-04                    21453       15.0
# 2020-02-05                    23551       18.0
# ...                             ...        ...
# 2020-05-27                    21330    11265.0
# 2020-05-28                    22614    11344.0
# 2020-05-29                    26455    11402.0
# 2020-05-30                    31377    11441.0
# 2020-05-31                    32146    11468.0
#
# [154 rows x 2 columns]

# %%
df_reg.columns = ['order','decide']

# %%
df_reg.to_csv('df_reg.csv')

# %%
df_covid
# Out:
#      seq   stateDt stateTime  decideCnt  clearCnt   examCnt  deathCnt  \
# 0      1  20200101     18:00          0       1.0       1.0       NaN
# 1      2  20200202      9:00          2       2.0       2.0       2.0
# 2      3  20200203      9:00         15       NaN       NaN       NaN
# 3      4  20200204      0:00         15       NaN       NaN       NaN
# 4      5  20200205      9:00         18       NaN     129.0       NaN
# ..   ...       ...       ...        ...       ...       ...       ...
# 580  591  20210802      0:00     201002  176605.0  387170.0    2099.0
# 581  592  20210803      0:00     202203  177909.0  398300.0    2104.0
# 582  593  20210804      0:00     203926  179123.0  397889.0    2106.0
# 583  594  20210805      0:00     205702  180719.0  415489.0    2109.0
# 584  595  20210806      0:00     207406  182052.0  427050.0    2113.0
#
#      careCnt  resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate createDt  \
# ...
