# %%
import pandas as pd

df = pd.read_csv('df_hour2.csv')

# %%
df
# Out:
#                code        date  stat    menu   sido   sigungu  amount  \
# 0        1156013200  2019-12-01     1   족발/보쌈  서울특별시      영등포구   18000
# 1        4128510200  2019-12-01     1      치킨    경기도  고양시 일산동구   21900
# 2        4115010100  2019-12-01     1      치킨    경기도      의정부시   19500
# 3        4128510400  2019-12-01     1  돈까스/일식    경기도  고양시 일산동구   18000
# 4        4115010900  2019-12-01     1      치킨    경기도      의정부시   18000
# ...             ...         ...   ...     ...    ...       ...     ...
# 4220987  4121010200  2020-03-31     1   족발/보쌈    경기도       광명시   20900
# 4220988  1156013300  2020-03-31     1      치킨  서울특별시      영등포구   26000
# 4220989  4127110400  2020-03-31     1      분식    경기도   안산시 상록구   17000
# 4220990  4128112300  2020-03-31     1   족발/보쌈    경기도   고양시 덕양구   35000
# 4220991  1154510200  2020-03-31     1      야식  서울특별시       금천구   30000
#
#                         time hour
# 0        2019-12-01 20:47:52   저녁
# 1        2019-12-01 21:58:07   저녁
# ...

# %%
df2 = pd.read_csv('df_age2.csv')
df2
# Out:
#          Unnamed: 0      date       행정동코드      총생활인구수      men    women  \
# 0                 0  20191201  11215710.0  45694.9988  23013.0  22682.0
# 1                 1  20191201  11680545.0  37375.4506  18005.0  19370.0
# 2                 2  20191201  11680610.0  37266.9526  19173.0  18094.0
# 3                 3  20191201  11680655.0  25231.2064  11956.0  13276.0
# 4                 4  20191201  11710570.0  40728.5564  18811.0  21917.0
# ...             ...       ...         ...         ...      ...      ...
# 1862203      315451  20200131  11260690.0  20052.7278   9545.0  10507.0
# 1862204      315452  20200131  11140570.0   7758.9907   4333.0   3426.0
# 1862205      315453  20200131  11590605.0  34441.9618  16253.0  18189.0
# 1862206      315454  20200131  11215760.0  17221.9293   8136.0   9086.0
# 1862207      315455  20200131  11200580.0  15466.1528   6921.0   8545.0
#
#                0~9      10~19       20~29      30~39      40~49      50~59  \
# ...

# %%
df2['date'] = pd.to_datetime(df2['date'])

# %%
df2['date'] = df2['date'].astype(str)

# %%
df2
# Out:
#          Unnamed: 0       date       행정동코드      총생활인구수      men    women  \
# 0                 0 2019-12-01  11215710.0  45694.9988  23013.0  22682.0
# 1                 1 2019-12-01  11680545.0  37375.4506  18005.0  19370.0
# 2                 2 2019-12-01  11680610.0  37266.9526  19173.0  18094.0
# 3                 3 2019-12-01  11680655.0  25231.2064  11956.0  13276.0
# 4                 4 2019-12-01  11710570.0  40728.5564  18811.0  21917.0
# ...             ...        ...         ...         ...      ...      ...
# 1862203      315451 2020-01-31  11260690.0  20052.7278   9545.0  10507.0
# 1862204      315452 2020-01-31  11140570.0   7758.9907   4333.0   3426.0
# 1862205      315453 2020-01-31  11590605.0  34441.9618  16253.0  18189.0
# 1862206      315454 2020-01-31  11215760.0  17221.9293   8136.0   9086.0
# 1862207      315455 2020-01-31  11200580.0  15466.1528   6921.0   8545.0
#
#                0~9      10~19       20~29      30~39      40~49      50~59  \
# ...

# %%
df2
# Out:
#          Unnamed: 0                           date       행정동코드      총생활인구수  \
# 0                 0  1970-01-01 00:00:00.020191201  11215710.0  45694.9988
# 1                 1  1970-01-01 00:00:00.020191201  11680545.0  37375.4506
# 2                 2  1970-01-01 00:00:00.020191201  11680610.0  37266.9526
# 3                 3  1970-01-01 00:00:00.020191201  11680655.0  25231.2064
# 4                 4  1970-01-01 00:00:00.020191201  11710570.0  40728.5564
# ...             ...                            ...         ...         ...
# 1862203      315451  1970-01-01 00:00:00.020200131  11260690.0  20052.7278
# 1862204      315452  1970-01-01 00:00:00.020200131  11140570.0   7758.9907
# 1862205      315453  1970-01-01 00:00:00.020200131  11590605.0  34441.9618
# 1862206      315454  1970-01-01 00:00:00.020200131  11215760.0  17221.9293
# 1862207      315455  1970-01-01 00:00:00.020200131  11200580.0  15466.1528
#
# ...

# %%
df3 = df2.sort_values(by=['date'])

# %%
del df2['Unnamed: 0']

# %%
df3['행정동코드'] = df3['행정동코드'].astype(int)
df3.rename(columns = {"행정동코드": "code"}, inplace = True)

df3
# Out:
#               date      code      총생활인구수      men    women        0~9  \
# 0       2019-12-01  11215710  45694.9988  23013.0  22682.0   840.7942
# 6780    2019-12-01  11140645   9006.1380   4109.0   4898.0   552.3101
# 6781    2019-12-01  11110530  28369.4532  12532.0  15837.0  1456.7707
# 6782    2019-12-01  11470530  19986.4449   9227.0  10760.0  1393.4457
# 6783    2019-12-01  11290770  15210.7480   7122.0   8088.0   852.3104
# ...            ...       ...         ...      ...      ...        ...
# 1539969 2020-05-31  11650510  25630.2751  12692.0  12939.0  2116.4477
# 1539970 2020-05-31  11350560  27094.6789  13684.0  13411.0  1926.6368
# 1539971 2020-05-31  11560670   6623.5933   3157.0   3466.0   345.2608
# 1539964 2020-05-31  11215770  30014.6155  13788.0  16227.0  1790.4869
# 1546751 2020-05-31  11350580  30747.9183  14435.0  16313.0  2933.4469
#
#              10~19       20~29      30~39      40~49      50~59      60~69  \
# ...

# %%
df
# Out:
#                code        date  stat    menu   sido   sigungu  amount  \
# 0        1156013200  2019-12-01     1   족발/보쌈  서울특별시      영등포구   18000
# 1        4128510200  2019-12-01     1      치킨    경기도  고양시 일산동구   21900
# 2        4115010100  2019-12-01     1      치킨    경기도      의정부시   19500
# 3        4128510400  2019-12-01     1  돈까스/일식    경기도  고양시 일산동구   18000
# 4        4115010900  2019-12-01     1      치킨    경기도      의정부시   18000
# ...             ...         ...   ...     ...    ...       ...     ...
# 4220987  4121010200  2020-03-31     1   족발/보쌈    경기도       광명시   20900
# 4220988  1156013300  2020-03-31     1      치킨  서울특별시      영등포구   26000
# 4220989  4127110400  2020-03-31     1      분식    경기도   안산시 상록구   17000
# 4220990  4128112300  2020-03-31     1   족발/보쌈    경기도   고양시 덕양구   35000
# 4220991  1154510200  2020-03-31     1      야식  서울특별시       금천구   30000
#
#                         time hour
# 0        2019-12-01 20:47:52   저녁
# 1        2019-12-01 21:58:07   저녁
# ...

# %%
df_del = pd.read_csv('./dlvr_call.csv', low_memory=False)

# %%
df['code'] = df_del['DLVR_DSTN_ADSTRD_CODE'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-1551bf6022b5> in <module>
# ----> 1 df['code'] = df_del['DLVR_DSTN_ADSTRD_CODE'].astype(float)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
# ...

# %%
df['']
# Out:
#                code        date  stat    menu   sido   sigungu  amount  \
# 0        1159066000  2019-12-01     1   족발/보쌈  서울특별시      영등포구   18000
# 1        4128552000  2019-12-01     1      치킨    경기도  고양시 일산동구   21900
# 2        4115062000  2019-12-01     1      치킨    경기도      의정부시   19500
# 3        4128556000  2019-12-01     1  돈까스/일식    경기도  고양시 일산동구   18000
# 4        4115058000  2019-12-01     1      치킨    경기도      의정부시   18000
# ...             ...         ...   ...     ...    ...       ...     ...
# 4220987  1132068100  2020-03-31     1   족발/보쌈    경기도       광명시   20900
# 4220988  4115052000  2020-03-31     1      치킨  서울특별시      영등포구   26000
# 4220989  4115054500  2020-03-31     1      분식    경기도   안산시 상록구   17000
# 4220990  1153072000  2020-03-31     1   족발/보쌈    경기도   고양시 덕양구   35000
# 4220991  4117360000  2020-03-31     1      야식  서울특별시       금천구   30000
#
#                         time hour
# 0        2019-12-01 20:47:52   저녁
# 1        2019-12-01 21:58:07   저녁
# ...

# %%
df3['code'] = df['code']/100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
#
# ...

# %%
df
# Out:
#                code        date  stat    menu   sido   sigungu  amount  \
# 0        11560132.0  2019-12-01     1   족발/보쌈  서울특별시      영등포구   18000
# 1        41285102.0  2019-12-01     1      치킨    경기도  고양시 일산동구   21900
# 2        41150101.0  2019-12-01     1      치킨    경기도      의정부시   19500
# 3        41285104.0  2019-12-01     1  돈까스/일식    경기도  고양시 일산동구   18000
# 4        41150109.0  2019-12-01     1      치킨    경기도      의정부시   18000
# ...             ...         ...   ...     ...    ...       ...     ...
# 4220987  41210102.0  2020-03-31     1   족발/보쌈    경기도       광명시   20900
# 4220988  11560133.0  2020-03-31     1      치킨  서울특별시      영등포구   26000
# 4220989  41271104.0  2020-03-31     1      분식    경기도   안산시 상록구   17000
# 4220990  41281123.0  2020-03-31     1   족발/보쌈    경기도   고양시 덕양구   35000
# 4220991  11545102.0  2020-03-31     1      야식  서울특별시       금천구   30000
#
#                         time hour
# 0        2019-12-01 20:47:52   저녁
# 1        2019-12-01 21:58:07   저녁
# ...

# %%
df['code'] = df['code'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-0e7dc6f5778d> in <module>
# ----> 1 df['code'] = df['code'].astype(float)
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
df.dtypes
# Out:
# code       object
# date       object
# stat        int64
# menu       object
# sido       object
# sigungu    object
# amount      int64
# time       object
# hour       object
# dtype: object

# %%
df3.dtypes
# Out:
# date       object
# code       object
# 총생활인구수    float64
# men       float64
# women     float64
# 0~9       float64
# 10~19     float64
# 20~29     float64
# 30~39     float64
# 40~49     float64
# 50~59     float64
# 60~69     float64
# 70~       float64
# dtype: object

# %%
df3
# Out:
#                date      code      총생활인구수      men    women        0~9  \
# 0        2019-12-01  11215710  45694.9988  23013.0  22682.0   840.7942
# 6780     2019-12-01  11140645   9006.1380   4109.0   4898.0   552.3101
# 6781     2019-12-01  11110530  28369.4532  12532.0  15837.0  1456.7707
# 6782     2019-12-01  11470530  19986.4449   9227.0  10760.0  1393.4457
# 6783     2019-12-01  11290770  15210.7480   7122.0   8088.0   852.3104
# ...             ...       ...         ...      ...      ...        ...
# 1539969  2020-05-31  11650510  25630.2751  12692.0  12939.0  2116.4477
# 1539970  2020-05-31  11350560  27094.6789  13684.0  13411.0  1926.6368
# 1539971  2020-05-31  11560670   6623.5933   3157.0   3466.0   345.2608
# 1539964  2020-05-31  11215770  30014.6155  13788.0  16227.0  1790.4869
# 1546751  2020-05-31  11350580  30747.9183  14435.0  16313.0  2933.4469
#
#              10~19       20~29      30~39      40~49      50~59      60~69  \
# ...

# %%
df
# Out:
#                code        date  stat    menu   sido   sigungu  amount  \
# 0        1159066000  2019-12-01     1   족발/보쌈  서울특별시      영등포구   18000
# 1        4128552000  2019-12-01     1      치킨    경기도  고양시 일산동구   21900
# 2        4115062000  2019-12-01     1      치킨    경기도      의정부시   19500
# 3        4128556000  2019-12-01     1  돈까스/일식    경기도  고양시 일산동구   18000
# 4        4115058000  2019-12-01     1      치킨    경기도      의정부시   18000
# ...             ...         ...   ...     ...    ...       ...     ...
# 4220987  1132068100  2020-03-31     1   족발/보쌈    경기도       광명시   20900
# 4220988  4115052000  2020-03-31     1      치킨  서울특별시      영등포구   26000
# 4220989  4115054500  2020-03-31     1      분식    경기도   안산시 상록구   17000
# 4220990  1153072000  2020-03-31     1   족발/보쌈    경기도   고양시 덕양구   35000
# 4220991  4117360000  2020-03-31     1      야식  서울특별시       금천구   30000
#
#                         time hour
# 0        2019-12-01 20:47:52   저녁
# 1        2019-12-01 21:58:07   저녁
# ...

# %%
df_fin = df.merge(df3, on=['date','code'], how='left')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-84-8f54d1ddd83e> in <module>
# ----> 1 df_fin = df.merge(df3, on=['code'], how='left')
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7961             copy=copy,
#    7962             indicator=indicator,
# -> 7963             validate=validate,
#    7964         )
#    7965
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ...

# %%
df_fin.iloc[:25 :]
# Out:
#           code        date  stat   menu   sido sigungu  amount  \
# 0   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 1   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 2   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 3   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 4   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 5   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 6   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 7   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 8   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 9   1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 10  1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 11  1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 12  1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# 13  1159066000  2019-12-01     1  족발/보쌈  서울특별시    영등포구   18000
# ...

# %%
df_del['DLVR_DSTN_ADSTRD_CODE']
# Out:
# 0          1159066000
# 1          4128552000
# 2          4115062000
# 3          4128556000
# 4          4115058000
#               ...
# 4296266    4121059000
# 4296267    1162065500
# 4296268    4127353500
# 4296269    4128165500
# 4296270    1154563000
# Name: DLVR_DSTN_ADSTRD_CODE, Length: 4296271, dtype: object

# %%
df
# Out:
#                code        date  stat    menu   sido   sigungu  amount  \
# 0        1159066000  2019-12-01     1   족발/보쌈  서울특별시      영등포구   18000
# 1        4128552000  2019-12-01     1      치킨    경기도  고양시 일산동구   21900
# 2        4115062000  2019-12-01     1      치킨    경기도      의정부시   19500
# 3        4128556000  2019-12-01     1  돈까스/일식    경기도  고양시 일산동구   18000
# 4        4115058000  2019-12-01     1      치킨    경기도      의정부시   18000
# ...             ...         ...   ...     ...    ...       ...     ...
# 4220987  1132068100  2020-03-31     1   족발/보쌈    경기도       광명시   20900
# 4220988  4115052000  2020-03-31     1      치킨  서울특별시      영등포구   26000
# 4220989  4115054500  2020-03-31     1      분식    경기도   안산시 상록구   17000
# 4220990  1153072000  2020-03-31     1   족발/보쌈    경기도   고양시 덕양구   35000
# 4220991  4117360000  2020-03-31     1      야식  서울특별시       금천구   30000
#
#                         time hour
# 0        2019-12-01 20:47:52   저녁
# 1        2019-12-01 21:58:07   저녁
# ...

# %%
df3['code'] = df3['code'].astype(str)

# %%
df3['code'] = df3['code']*100

# %%
df3
# Out:
#                date        code      총생활인구수      men    women        0~9  \
# 0        2019-12-01  1121571000  45694.9988  23013.0  22682.0   840.7942
# 6780     2019-12-01  1114064500   9006.1380   4109.0   4898.0   552.3101
# 6781     2019-12-01  1111053000  28369.4532  12532.0  15837.0  1456.7707
# 6782     2019-12-01  1147053000  19986.4449   9227.0  10760.0  1393.4457
# 6783     2019-12-01  1129077000  15210.7480   7122.0   8088.0   852.3104
# ...             ...         ...         ...      ...      ...        ...
# 1539969  2020-05-31  1165051000  25630.2751  12692.0  12939.0  2116.4477
# 1539970  2020-05-31  1135056000  27094.6789  13684.0  13411.0  1926.6368
# 1539971  2020-05-31  1156067000   6623.5933   3157.0   3466.0   345.2608
# 1539964  2020-05-31  1121577000  30014.6155  13788.0  16227.0  1790.4869
# 1546751  2020-05-31  1135058000  30747.9183  14435.0  16313.0  2933.4469
#
#              10~19       20~29      30~39      40~49      50~59      60~69  \
# ...

# %%
df4 = df3.groupby(['date', 'code']).mean()

# %%
print(77592 * 24)
# Out:
# 1862208

# %%
df4
# Out:
#                              총생활인구수           men         women          0~9  \
# date       code
# 2019-12-01 1111051500  15075.553533   7192.875000   7882.666667   828.791613
#            1111053000  21424.196900   9752.708333  11671.541667  1048.933158
#            1111054000   5250.678642   2615.750000   2634.958333   199.033621
#            1111055000  16209.533550   7365.708333   8843.791667   763.729050
#            1111056000  19365.692483   8941.125000  10424.666667  1247.823371
# ...                             ...           ...           ...          ...
# 2020-05-31 1174065000  26722.064971  12466.666667  14255.333333  1832.575479
#            1174066000  27274.709062  13299.000000  13975.583333  1541.204471
#            1174068500  52817.007617  24740.916667  28076.125000  3787.572396
#            1174069000   7866.831029   3814.416667   4052.458333   554.088588
#            1174070000  28599.459583  13790.583333  14808.958333  1919.739171
#
# ...

# %%
df4 = df4.reset_index()

# %%
df4.dtypes
# Out:
# date       object
# code       object
# 총생활인구수    float64
# men       float64
# women     float64
# 0~9       float64
# 10~19     float64
# 20~29     float64
# 30~39     float64
# 40~49     float64
# 50~59     float64
# 60~69     float64
# 70~       float64
# dtype: object

# %%
df
# Out:
#                code        date  stat    menu   sido   sigungu  amount  \
# 0        1159066000  2019-12-01     1   족발/보쌈  서울특별시      영등포구   18000
# 1        4128552000  2019-12-01     1      치킨    경기도  고양시 일산동구   21900
# 2        4115062000  2019-12-01     1      치킨    경기도      의정부시   19500
# 3        4128556000  2019-12-01     1  돈까스/일식    경기도  고양시 일산동구   18000
# 4        4115058000  2019-12-01     1      치킨    경기도      의정부시   18000
# ...             ...         ...   ...     ...    ...       ...     ...
# 4220987  1132068100  2020-03-31     1   족발/보쌈    경기도       광명시   20900
# 4220988  4115052000  2020-03-31     1      치킨  서울특별시      영등포구   26000
# 4220989  4115054500  2020-03-31     1      분식    경기도   안산시 상록구   17000
# 4220990  1153072000  2020-03-31     1   족발/보쌈    경기도   고양시 덕양구   35000
# 4220991  4117360000  2020-03-31     1      야식  서울특별시       금천구   30000
#
#                         time hour
# 0        2019-12-01 20:47:52   저녁
# 1        2019-12-01 21:58:07   저녁
# ...

# %%
df4
# Out:
#              date        code        총생활인구수           men         women  \
# 0      2019-12-01  1111051500  15075.553533   7192.875000   7882.666667
# 1      2019-12-01  1111053000  21424.196900   9752.708333  11671.541667
# 2      2019-12-01  1111054000   5250.678642   2615.750000   2634.958333
# 3      2019-12-01  1111055000  16209.533550   7365.708333   8843.791667
# 4      2019-12-01  1111056000  19365.692483   8941.125000  10424.666667
# ...           ...         ...           ...           ...           ...
# 77587  2020-05-31  1174065000  26722.064971  12466.666667  14255.333333
# 77588  2020-05-31  1174066000  27274.709062  13299.000000  13975.583333
# 77589  2020-05-31  1174068500  52817.007617  24740.916667  28076.125000
# 77590  2020-05-31  1174069000   7866.831029   3814.416667   4052.458333
# 77591  2020-05-31  1174070000  28599.459583  13790.583333  14808.958333
#
#                0~9        10~19        20~29        30~39        40~49  \
# ...

# %%
df_fin = df.merge(df4, on=['date','code'], how='inner')

# %%
df_fin
# Out:
#               code        date  stat    menu   sido  sigungu  amount  \
# 0       1159066000  2019-12-01     1   족발/보쌈  서울특별시     영등포구   18000
# 1       1159066000  2019-12-01     1   족발/보쌈  서울특별시      동작구   43000
# 2       1159066000  2019-12-01     1      치킨    경기도  안양시 동안구   16000
# 3       1159066000  2019-12-01     1      분식    경기도  안산시 상록구   15000
# 4       1159066000  2019-12-01     1   족발/보쌈    경기도     의정부시   30000
# ...            ...         ...   ...     ...    ...      ...     ...
# 977377  1165062000  2020-03-31     1  카페/디저트    경기도      파주시   22000
# 977378  1165062000  2020-03-31     1  카페/디저트    경기도      부천시   19200
# 977379  1165062000  2020-03-31     1  카페/디저트    경기도      파주시   22000
# 977380  1165062000  2020-03-31     1   패스트푸드    경기도     의정부시   12200
# 977381  1165057000  2020-03-31     1      치킨    경기도      광명시   23900
#
#                        time hour        총생활인구수           men         women  \
# ...

# %%
df_fin = round(df_fin)

# %%
df_fin.to_csv('df_fin.csv')

# %%
df.to_csv('df_Time.csv')

# %%
df4.to_csv('df_age3.csv')

# %%
delshop = pd.read_csv('del_shop.csv', header=None)
delshop2 = pd.read_csv('del_shop2.csv', header=None)
delshop3 = pd.read_csv('del_shop3.csv', header=None)
delshop4 = pd.read_csv('del_shop4.csv', header=None)
delshop5 = pd.read_csv('del_shop5.csv', header=None)
delshop6 = pd.read_csv('del_shop6.csv', header=None)
delshop7 = pd.read_csv('del_shop7.csv', header=None)
delshop8 = pd.read_csv('del_shop8.csv', header=None)
delshop9 = pd.read_csv('del_shop9.csv', header=None)
delshop10 = pd.read_csv('del_shop10.csv', header=None)

# %%
delshop2
# Out:
#              0       1           2      3     4    5    6           7     8   \
# 0      S0000001      치킨  4817012500   경상남도   진주시  신안동   \N  4817071500   신안동
# 1      S0000002      치킨  1130510100  서울특별시   강북구  미아동   \N  1130553400   삼양동
# 2      S0000003  카페/디저트  2644010400  부산광역시   강서구  명지동   \N  2644054500  명지2동
# 3      S0000004      한식  1130510100  서울특별시   강북구  미아동   \N  1130555500   송천동
# 4      S0000005      치킨  1130510100  서울특별시   강북구  미아동   \N  1130555500   송천동
# ...         ...     ...         ...    ...   ...  ...  ...         ...   ...
# 42764  S0045503      분식  4115010900    경기도  의정부시  금오동   \N  4115058000   자금동
# 42765  S0045504      중식  4122025330    경기도   평택시  안중읍  현화리  4122025300   안중읍
# 42766  S0045505      중식  4165034021    경기도   포천시  신북면  가채리  4165034000   신북면
# 42767  S0045506      분식  4115010200    경기도  의정부시  호원동   \N  4115055500  호원2동
# 42768  S0045507      한식  4115010200    경기도  의정부시  호원동   \N  4115055500  호원2동
#
#                  9         10
# ...

# %%
del_shop = pd.concat([delshop,delshop2,delshop3,delshop4,delshop5,delshop6,delshop7,delshop8,delshop9])

# %%
(del_shop[1] == '테스트')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 42764    False
# 42765    False
# 42766    False
# 42767    False
# 42768    False
# Name: 1, Length: 195286, dtype: bool

# %%
del_shop2 = del_shop[[1,7]]

# %%
del_shop2['2'] = 1
# Out:
# c:\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
del_shop3 = del_shop2.groupby([7,1]).sum()

# %%
del_shop2.dtypes
# Out:
# 1    object
# 7    object
# dtype: object

# %%
del_shop3.shape
# Out:
# (7650, 1)

# %%
del_shop3.tail(500)
# Out:
#                      2
# 7          1
# 4790036000 야식        1
#            치킨        1
#            한식        1
# 4812154000 카페/디저트    1
# 4812353000 회         1
# ...                ...
# \N         카페/디저트   48
#            패스트푸드    15
#            피자       31
#            한식      109
#            회        23
#
# [500 rows x 1 columns]

# %%
del_shop3 = del_shop3.reset_index()

# %%
del_shop3[7].unique()
# Out:
# array([1111053000, 1117053000, 1117069000, ..., '5013061000',
#        '5013062000', '\\N'], dtype=object)

# %%
del_shop3
# Out:
#                7       1    2
# 0     1111053000     테스트    6
# 1     1117053000     테스트    3
# 2     1117069000     심부름    3
# 3     1123053600     심부름    3
# 4     1123065000     심부름    3
# ...          ...     ...  ...
# 7645          \N  카페/디저트   48
# 7646          \N   패스트푸드   15
# 7647          \N      피자   31
# 7648          \N      한식  109
# 7649          \N       회   23
#
# [7650 rows x 3 columns]

# %%
del_shop4 = del_shop3.iloc[:7634]

# %%
del_shop4.columns = ['code','menu','count']

# %%
del_shop4.to_csv('del_shopfin.csv')
